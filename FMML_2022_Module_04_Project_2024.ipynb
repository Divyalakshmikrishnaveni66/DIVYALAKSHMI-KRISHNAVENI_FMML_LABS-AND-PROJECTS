# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyalakshmikrishnaveni66/DIVYALAKSHMI-KRISHNAVENI_FMML_LABS-AND-PROJECTS/blob/main/FMML_2022_Module_04_Project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################TASK 1
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

def df(x):
    # [REQUIRED] Define the derivative (slope) of your function here
    return 2 * x - 4

def f(x):
    # [REQUIRED] Define your function here
    return x**2 - 4*x + 4

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [REQUIRED] Calculate the gradient (slope) at current x
    new_x = previous_x - step_multiplier * gradient  # [REQUIRED] Update x using gradient descent

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 45
# Local minimum occurs at: 2.000034844914373
# Slope or df(x) value at this point is: 6.968982874600016e-05
# f(x) value or cost at this point is: 1.2141683214395016e-09

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
import numpy as np
import matplotlib.pyplot as plt

##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2  ## [REQUIRED] Define your function g(x) here

def dg(x):
    return 2*x  ## [REQUIRED] Define the derivative of g(x) here

# Plotting
plt.figure(figsize=(12, 4))

# Plot the function g(x)
plt.subplot(1, 2, 1)
plt.plot(x_2, g(x_2), label='g(x)')
plt.title('Function g(x)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

# Plot the derivative dg(x)
plt.subplot(1, 2, 2)
plt.plot(x_2, dg(x_2), label='dg(x)', color='orange')
plt.title('Derivative dg(x)')
plt.xlabel('x')
plt.ylabel('dg(x)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier
import numpy as np
import matplotlib.pyplot as plt

##########################
##########################



##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**3  ## [REQUIRED] Define your function g(x) here

def dg(x):
    return 3*x**2  ## [REQUIRED] Define the derivative of g(x) here

# Plotting
plt.figure(figsize=(12, 4))

# Plot the function g(x)
plt.subplot(1, 2, 1)
plt.plot(x_2, g(x_2), label='g(x)')
plt.title('Function g(x)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

# Plot the derivative dg(x)
plt.subplot(1, 2, 2)
plt.plot(x_2, dg(x_2), label='dg(x)', color='orange')
plt.title('Derivative dg(x)')
plt.xlabel('x')
plt.ylabel('dg(x)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.12750753328087513
# Number of steps: 97

# %%
def gradient_descent(derivative_func, initial_guess, multiplier, precision):
    current_x = initial_guess
    list_x = [current_x]
    deriv_list = [derivative_func(current_x)]

    while abs(derivative_func(current_x)) > precision:
        new_x = current_x - multiplier * derivative_func(current_x)
        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))
        current_x = new_x

    return current_x, list_x, deriv_list

# Example function dg (you need to replace this with your actual derivative function)
def dg(x):
    return 2 * x  # Replace this with the actual derivative of your function

# Usage
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.5,
                                                 multiplier=0.01, precision=0.0001)

# Output results
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -4.989540132102885e-05
# Number of steps: 457

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=1e-6):
    current_x = initial_guess
    list_x = [current_x]
    deriv_list = [derivative_func(current_x)]

    while abs(derivative_func(current_x)) > precision:
        new_x = current_x - multiplier * derivative_func(current_x)
        list_x.append(new_x)
        deriv_list.append(derivative_func(new_x))
        current_x = new_x

    return current_x, list_x, deriv_list

# Example function dg (you need to replace this with your actual derivative function)
def dg(x):
    return 2 * x  # Replace this with the actual derivative of your function

# Usage
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -4.917855841128087e-07
# Number of steps: 606

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

# %%
## TASK-4 :
import numpy as np
import matplotlib.pyplot as plt

# Gradient Descent
def gradient_descent(x, df, learning_rate=0.1, precision=0.00001, max_iter=500):
    x_list = [x]
    slope_list = [df(x)]

    for n in range(max_iter):
        previous_x = x
        gradient = df(previous_x)
        x = previous_x - learning_rate * gradient

        step_size = abs(x - previous_x)

        x_list.append(x)
        slope_list.append(df(x))

        if step_size < precision:
            print('Loop ran this many times:', n)
            break

    return x_list, slope_list

# Define the function g(x) and its derivative dg(x)
def g(x):
    return x**2

def dg(x):
    return 2*x

# Initial values
initial_x = 3
learning_rate = 0.1
precision = 0.00001

# Perform gradient descent
x_values, slope_values = gradient_descent(initial_x, dg, learning_rate, precision)

# Plotting the function and its derivative
plt.figure(figsize=(12, 4))

# Plot the function g(x)
plt.subplot(1, 2, 1)
plt.plot(x_2, g(x_2), label='g(x)')
plt.scatter(x_values, [g(x) for x in x_values], color='red', label='Gradient Descent Path')
plt.title('Function g(x) and Gradient Descent')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

# Plot the derivative dg(x)
plt.subplot(1, 2, 2)
plt.plot(x_2, dg(x_2), label='dg(x)', color='orange')
plt.scatter(x_values, slope_values, color='red', label='Gradient Descent Slopes')
plt.title('Derivative dg(x) and Gradient Descent')
plt.xlabel('x')
plt.ylabel('dg(x)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Loop ran this many times: 50

# %% [markdown]
# # The Learning Rate

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, max_iter=500):
    x = initial_guess
    list_x = [x]
    deriv_list = [derivative_func(x)]

    for i in range(max_iter):
        x = x - multiplier * derivative_func(x)
        list_x.append(x)
        deriv_list.append(derivative_func(x))

    return x, list_x, deriv_list

# Define the function g(x) and its derivative dg(x)
def g(x):
    return x**2

def dg(x):
    return 2*x

# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=1.9,
                                                  multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side
x_2 = np.linspace(-2, 2, 1000)

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0, 5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  501

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  501

# %%
## TASK-5 : Run gradient descent 3 times
import numpy as np
import matplotlib.pyplot as plt

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, max_iter=500):
    x = initial_guess
    list_x = [x]
    deriv_list = [derivative_func(x)]

    for i in range(max_iter):
        x = x - multiplier * derivative_func(x)
        list_x.append(x)
        deriv_list.append(derivative_func(x))

    return x, list_x, deriv_list

# Define the function g(x) and its derivative dg(x)
def g(x):
    return x**2

def dg(x):
    return 2*x

# Run gradient descent three times with different initial guesses
initial_guesses = [1.5, -1.5, 2.0]
results = []

for guess in initial_guesses:
    local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=guess,
                                                      multiplier=0.02, max_iter=500)
    results.append((local_min, list_x, deriv_list))

# Plot function and derivative and scatter plot for each run
x_2 = np.linspace(-2, 2, 1000)

plt.figure(figsize=[15, 10])

for i, (local_min, list_x, deriv_list) in enumerate(results, start=1):
    plt.subplot(3, 2, 2*i-1)
    plt.xlim(-2, 2)
    plt.ylim(0, 5)
    plt.title(f'Run {i}: Cost function', fontsize=14)
    plt.xlabel('X', fontsize=12)
    plt.ylabel('g(x)', fontsize=12)
    plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
    plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

    plt.subplot(3, 2, 2*i)
    plt.title(f'Run {i}: Slope of the cost function', fontsize=14)
    plt.xlabel('X', fontsize=12)
    plt.ylabel('dg(x)', fontsize=12)
    plt.grid()
    plt.xlim(-2, 2)
    plt.ylim(-6, 8)
    plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
    plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# %%
## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.00001, max_iter=500):
    x = initial_guess
    list_x = [x]
    deriv_list = [derivative_func(x)]

    for i in range(max_iter):
        x_new = x - multiplier * derivative_func(x)
        list_x.append(x_new)
        deriv_list.append(derivative_func(x_new))

        step_size = abs(x_new - x)
        if step_size < precision:
            break

        x = x_new

    return x, list_x, deriv_list

# Define the function g(x) and its derivative dg(x)
def g(x):
    return x**2

def dg(x):
    return 2*x

# Run gradient descent for different learning rates
n = 100

low_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.001, precision=0.0001, max_iter=n)

high_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                              multiplier=0.002, precision=0.0001, max_iter=n)

insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9,
                                multiplier=0.25, precision=0.0001, max_iter=n)

# Plot function and derivative and scatter plot for each learning rate
x_2 = np.linspace(-2, 2, 1000)

plt.figure(figsize=[15, 12])

# Low Gamma
plt.subplot(4, 2, 1)
plt.xlim(-2, 2)
plt.ylim(0, 5)
plt.title('Low Gamma: Cost function', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('g(x)', fontsize=12)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(low_gamma[1], g(np.array(low_gamma[1])), color='red', s=100, alpha=0.6)

plt.subplot(4, 2, 2)
plt.title('Low Gamma: Slope of the cost function', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('dg(x)', fontsize=12)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(low_gamma[1], low_gamma[2], color='red', s=100, alpha=0.5)

# Mid Gamma
plt.subplot(4, 2, 3)
plt.xlim(-2, 2)
plt.ylim(0, 5)
plt.title('Mid Gamma: Cost function', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('g(x)', fontsize=12)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(mid_gamma[1], g(np.array(mid_gamma[1])), color='red', s=100, alpha=0.6)

plt.subplot(4, 2, 4)
plt.title('Mid Gamma: Slope of the cost function', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('dg(x)', fontsize=12)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(mid_gamma[1], mid_gamma[2], color='red', s=100, alpha=0.5)

# High Gamma
plt.subplot(4, 2, 5)
plt.xlim(-2, 2)
plt.ylim(0, 5)
plt.title('High Gamma: Cost function', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('g(x)', fontsize=12)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(high_gamma[1], g(np.array(high_gamma[1])), color='red', s=100, alpha=0.6)

plt.subplot(4, 2, 6)
plt.title('High Gamma: Slope of the cost function', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('dg(x)', fontsize=12)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(high_gamma[1], high_gamma[2], color='red', s=100, alpha=0.5)

# Insane Gamma
plt.subplot(4, 2, 7)
plt.xlim(-2, 2)
plt.ylim(0, 5)
plt.title('Insane Gamma: Cost function', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('g(x)', fontsize=12)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(insane_gamma[1], g(np.array(insane_gamma[1])), color='red', s=100, alpha=0.6)

plt.subplot(4, 2, 8)
plt.title('Insane Gamma: Slope of the cost function', fontsize=14)
plt.xlabel('X', fontsize=12)
plt.ylabel('dg(x)', fontsize=12)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(insane_gamma[1], insane_gamma[2], color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# %%
## TASK-7 : Plot reduction in cost for each iteration

# %%
## TASK-7 : Plot reduction in cost for each iteration

## TASK-7 : Plot reduction in cost for each iteration
import numpy as np
import matplotlib.pyplot as plt

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.00001, max_iter=500):
    x = initial_guess
    list_x = [x]
    deriv_list = [derivative_func(x)]
    cost_list = [g(x)]

    for i in range(max_iter):
        x_new = x - multiplier * derivative_func(x)
        list_x.append(x_new)
        deriv_list.append(derivative_func(x_new))

        cost_new = g(x_new)
        cost_list.append(cost_new)

        step_size = abs(x_new - x)
        if step_size < precision:
            break

        x = x_new

    return x, list_x, deriv_list, cost_list

# Define the function g(x) and its derivative dg(x)
def g(x):
    return x**2

def dg(x):
    return 2*x

# Run gradient descent for different learning rates
n = 100

low_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.001, precision=0.0001, max_iter=n)

high_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                              multiplier=0.002, precision=0.0001, max_iter=n)

insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9,
                                multiplier=0.25, precision=0.0001, max_iter=n)

# Extract cost lists from results
cost_low_gamma = low_gamma[3]
cost_mid_gamma = mid_gamma[3]
cost_high_gamma = high_gamma[3]
cost_insane_gamma = insane_gamma[3]

# Plot cost reduction for each iteration
plt.figure(figsize=[15, 10])

# Low Gamma
plt.subplot(2, 2, 1)
plt.title('Low Gamma: Cost Reduction', fontsize=14)
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost Reduction', fontsize=12)
plt.plot(np.subtract(cost_low_gamma, np.min(cost_low_gamma)), label='Low Gamma', color='blue')
plt.legend()

# Mid Gamma
plt.subplot(2, 2, 2)
plt.title('Mid Gamma: Cost Reduction', fontsize=14)
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost Reduction', fontsize=12)
plt.plot(np.subtract(cost_mid_gamma, np.min(cost_mid_gamma)), label='Mid Gamma', color='orange')
plt.legend()

# High Gamma
plt.subplot(2, 2, 3)
plt.title('High Gamma: Cost Reduction', fontsize=14)
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost Reduction', fontsize=12)
plt.plot(np.subtract(cost_high_gamma, np.min(cost_high_gamma)), label='High Gamma', color='green')
plt.legend()

# Insane Gamma
plt.subplot(2, 2, 4)
plt.title('Insane Gamma: Cost Reduction', fontsize=14)
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost Reduction', fontsize=12)
plt.plot(np.subtract(cost_insane_gamma, np.min(cost_insane_gamma)), label='Insane Gamma', color='red')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples

# %%
## TASK-8 : Code the same things as they were done for the first two examples
import numpy as np
import matplotlib.pyplot as plt

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.00001, max_iter=500):
    x = initial_guess
    list_x = [x]
    deriv_list = [derivative_func(x)]
    cost_list = [f(x)]

    for i in range(max_iter):
        x_new = x - multiplier * derivative_func(x)
        list_x.append(x_new)
        deriv_list.append(derivative_func(x_new))

        cost_new = f(x_new)
        cost_list.append(cost_new)

        step_size = abs(x_new - x)
        if step_size < precision:
            break

        x = x_new

    return x, list_x, deriv_list, cost_list

# Define the function f(x) and its derivative df(x)
def f(x):
    return x**3 - 2*x**2 + 2

def df(x):
    return 3*x**2 - 4*x

# Run gradient descent
n = 100
local_min, list_x, deriv_list, cost_list = gradient_descent(derivative_func=df, initial_guess=1.5,
                                                             multiplier=0.02, precision=0.0001, max_iter=n)

# Plot function and derivative and scatter plot for the first example
x_values = np.linspace(-2, 3, 1000)
y_values = f(x_values)

plt.figure(figsize=[15, 5])

# Chart 1: Cost function
plt.subplot(1, 2, 1)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_values, y_values, color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, cost_list, color='red', s=100, alpha=0.6)

# Chart 2: Derivative
plt.subplot(1, 2, 2)
plt.title('Derivative of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.plot(x_values, df(x_values), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function to be optimized
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generating x, y values
x_4 = np.linspace(-6, 6, 30)
y_4 = np.linspace(-6, 6, 30)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f(x_4, y_4)  # Using the function f(x, y)

# Plotting in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.set_title('Surface Plot of f(x, y)', fontsize=20)
ax.set_xlabel('X-axis', fontsize=16)
ax.set_ylabel('Y-axis', fontsize=16)
ax.set_zlabel('f(x, y) - Cost', fontsize=16)

ax.plot_surface(x_4, y_4, z_4, cmap='coolwarm', alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %% [markdown]
# For the given function (f(x, y)), we need to compute the partial derivatives with respect to (x) and (y). Let's say the function is (f(x, y) = x^2 + 2y). Then, the partial derivatives are:
#
# [ \frac{\partial f}{\partial x} = 2x ]
#
# [ \frac{\partial f}{\partial y} = 2 ]
#
# You can replace the function (f(x, y)) with your specific function, and the corresponding partial derivatives would be calculated accordingly. If you have a specific function, please provide it so that I can give you the accurate partial derivatives.

# %%
from sympy import symbols, diff

a, b = symbols('x y')

# Given cost function
f = a**2 + 2*b

print('Our cost function f(x, y) is: ', f)
print('Partial derivative wrt x is: ', diff(f, a))
print('Partial derivative wrt y is: ', diff(f, b))

# Substitute values into the expressions
x_value = 1.8
y_value = 1.0

print('Value of f(x, y) at x=1.8, y=1.0 is: ', f.evalf(subs={a: x_value, b: y_value}))
print('Value of partial derivative wrt x at x=1.8, y=1.0: ', diff(f, a).evalf(subs={a: x_value, b: y_value}))
# Out:
# Our cost function f(x, y) is:  x**2 + 2*y
# Partial derivative wrt x is:  2*x
# Partial derivative wrt y is:  2
# Value of f(x, y) at x=1.8, y=1.0 is:  5.24000000000000
# Value of partial derivative wrt x at x=1.8, y=1.0:  3.60000000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess
f = a**2 + 2*b  # Replace with your specific cost function

for n in range(max_iter):
    gradient_x = diff(f, a).evalf(subs={a: params[0], b: params[1]})
    gradient_y = diff(f, b).evalf(subs={a: params[0], b: params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f.evalf(subs={a: params[0], b: params[1]}))
# Out:
# Values in gradient array: [1.57835979496953e-48 2.00000000000000]
# Minimum occurs at x value of: 6.31343917987813e-49
# Minimum occurs at y value of: -99.0000000000009
# The cost is: -198.000000000002

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
from sympy import symbols, diff

# Define symbols
a, b = symbols('x y')

# Define cost function
f = a**2 + 2*b  # Replace with your specific cost function

# Partial derivative functions
def fpx(x, y):
    return diff(f, a).evalf(subs={a: x, b: y})

def fpy(x, y):
    return diff(f, b).evalf(subs={a: x, b: y})

# Test the partial derivative functions
x_value = 1.8
y_value = 1.0

result_fpx = fpx(x_value, y_value)
result_fpy = fpy(x_value, y_value)

print('Partial derivative wrt x at x=1.8, y=1.0:', result_fpx)
print('Partial derivative wrt y at x=1.8, y=1.0:', result_fpy)
# Out:
# Partial derivative wrt x at x=1.8, y=1.0: 3.60000000000000
# Partial derivative wrt y at x=1.8, y=1.0: 2.00000000000000

# %%
# Define symbols and cost function
a, b = symbols('x y')
f = a**2 + 2*b  # Replace with your specific cost function

# Partial derivative functions
def fpx(x, y):
    return diff(f, a).evalf(subs={a: x, b: y})

def fpy(x, y):
    return diff(f, b).evalf(subs={a: x, b: y})

# Gradient descent setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f.evalf(subs={a: params[0], b: params[1]}))
# Out:
# Values in gradient array: [1.57835979496953e-48 2.00000000000000]
# Minimum occurs at x value of: 6.31343917987813e-49
# Minimum occurs at y value of: -99.0000000000009
# The cost is: -198.000000000002

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
import numpy as np

# Function to be minimized
def f(x, y):
    return x**2 + y**2

# Partial derivatives of the function
def fpx(x, y):
    return 2 * x

def fpy(x, y):
    return 2 * y

# Hyperparameters
multiplier = 0.1
max_iter = 200

# Initial guess
params = np.array([1.8, 1.0])
values_array = params.reshape(1, 2)

# Gradient Descent
for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)

    # Convergence criteria (you can adjust this)
    if np.linalg.norm(gradients) < 1e-5:
        print(f'Converged in {n} iterations.')
        break

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f(params[0], params[1]))
# Out:
# Converged in 58 iterations.
# Values in gradient array: [8.62028742e-06 4.78904857e-06]
# Minimum occurs at x value of: 3.4481149669482487e-06
# Minimum occurs at y value of: 1.915619426082362e-06
# The cost is: 1.555909461087664e-11

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
